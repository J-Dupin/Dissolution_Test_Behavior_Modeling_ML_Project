# %% [markdown]
# # Dissolution Stability Machine Learning Project Using a Gaussian Mixture Model
#
# ## Project Overview – Analyzing Dissolution Test Data with Gaussian Mixture Models
#
# **Goal:**
# Use FDA Dissolution Methods metadata + synthetic dissolution profiles to identify clusters of dissolution behaviors ("fast," "medium," "slow").
#
# **Steps:**
# 1. Feature Engineering from FDA database
# 2. Synthetic Profile Generation using kinetic models
# 3. GMM clustering and visualization
# 4. Interpretation & discussion of pharma relevance

# %% [markdown]
# ### 1. Notebook Setup
#
# Getting all the tools ready in the project's virtual environment.

# %%
# Setup matplotlib to plot inline (within the notebook)
# %matplotlib inline

# Core libraries
import pandas as pd
import numpy as np
import re

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# # Modeling
# from sklearn.preprocessing import StandardScaler
# from sklearn.mixture import GaussianMixture
# from sklearn.metrics import silhouette_score

# Utility
from tqdm import tqdm

# Ensure pandas prints enough rows and columns without truncation
pd.set_option("display.max_rows", 200)        # show up to 100 rows
pd.set_option("display.max_columns", None)    # show all columns
pd.set_option("display.width", None)          # don't wrap to fit terminal width
pd.set_option("display.max_colwidth", None)   # show full cell content

# %% [markdown]
# ### 2. Data Acquisition
#
# The FDA Dissolution Methods Database contains:
# - Dosage form
# - Apparatus type
# - Agitation speed (RPM)
# - Medium type & volume
# - Sampling times
#
# These features can be parsed into a structured table for feature engineering.

# %% [markdown]
# Loading the dataset (if dataset is real and available).

# %%
# Import dataset from CSV file or URL
df = pd.read_csv("Dissolution Methods.csv")

# Quick check to view the data
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1568 entries, 0 to 1567
# Data columns (total 8 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Drug Name                             1568 non-null   object
#  1   Dosage Form                           1568 non-null   object
#  2   USP Apparatus                         805 non-null    object
#  3   Speed (RPMs)                          800 non-null    object
#  4   Medium                                1568 non-null   object
#  5   Volume (mL)                           792 non-null    object
#  6   Recommended Sampling Times (minutes)  803 non-null    object
#  7   Date Updated                          1568 non-null   object
# dtypes: object(8)
# memory usage: 98.1+ KB
#                                          Drug Name              Dosage Form  \
# 0                                 Abacavir Sulfate                   Tablet
# 1  Abacavir Sulfate/Dolutegravir Sodium/Lamivudine                   Tablet
# 2  Abacavir Sulfate/Dolutegravir Sodium/Lamivudine  Tablet (For Suspension)
# 3                      Abacavir Sulfate/Lamivudine                   Tablet
# 4           Abacavir Sulfate/Lamivudine/Zidovudine                   Tablet
#
#   USP Apparatus Speed (RPMs)  \
# 0           NaN          NaN
# 1   II (Paddle)           85
# 2   II (Paddle)           50
# 3   II (Paddle)           75
# 4   II (Paddle)           75
#
#                                                                    Medium  \
# 0                               Refer to FDA's Dissolution Guidance, 2018
# 1  0.01 M Phosphate Buffer with 0.5% sodium dodecyl sulfate (SDS), pH 6.8
# 2                        0.01 M Phosphate Buffer with 0.5 mM EDTA, pH 6.8
# 3                                                               0.1 N HCl
# 4                                                               0.1 N HCl
#
#                                  Volume (mL)  \
# 0                                        NaN
# 1                                        900
# 2                                        500
# 3                                        900
# 4  Acid Stage: 900 mL; Buffer Stage: 1000 mL
#
#                                                  Recommended Sampling Times (minutes)  \
# 0                                                                                 NaN
# 1  Abacavir and lamivudine: 10, 15, 20, 30 and 45; Dolutegravir: 5,15, 25, 35 and 45.
# 2                                                            5, 10, 15, 30, 45 and 60
# 3                                                                 10, 20, 30, and 45
# 4                                                                5, 10, 15, 30 and 45
#
#   Date Updated
# 0   07/02/2020
# 1   05/28/2015
# 2   10/06/2023
# 3   01/03/2007
# 4   01/03/2007

# %% [markdown]
# Simulating the dataset (if dataset if not available). (OPTIONAL)

# %%
# # Simulating dissolution test metrics for 200 batches
# np.random.seed(42)
# fast_group = np.random.normal(
#     loc=90, scale=5, size=(100, 3))  # high % dissolved
# slow_group = np.random.normal(
#     loc=60, scale=5, size=(100, 3))  # lower % dissolved
# synthetic_data = np.vstack([fast_group, slow_group])

# df = pd.DataFrame(synthetic_data, columns=["% Dissolved @ 5min", "% Dissolved @ 10min", "% Dissolved @ 15min"])

# %% [markdown]
# ### 3. Data Cleaning, Preprocessing, and Feature Engineering
#
# Prepare the dataset for use within the model. Convert the FDA method metadata into ML-ready features:
#
# - Apparatus → categorical → one-hot encode
# - Medium type → categorical → one-hot encode
# - RPM → numerical
# - Medium volume → numerical
# - Sampling times → numerical summary features (e.g., # of samples, max time)

# %% [markdown]
# #### 3.1. Data Cleaning
#
# Ensuring numerical features are clean and scaled.

# %%
print(len(df))
# Out:
# 1568

# %%
df.head()
# Out:
#                                          Drug Name              Dosage Form  \
# 0                                 Abacavir Sulfate                   Tablet
# 1  Abacavir Sulfate/Dolutegravir Sodium/Lamivudine                   Tablet
# 2  Abacavir Sulfate/Dolutegravir Sodium/Lamivudine  Tablet (For Suspension)
# 3                      Abacavir Sulfate/Lamivudine                   Tablet
# 4           Abacavir Sulfate/Lamivudine/Zidovudine                   Tablet
#
#   USP Apparatus Speed (RPMs)  \
# 0           NaN          NaN
# 1   II (Paddle)           85
# 2   II (Paddle)           50
# 3   II (Paddle)           75
# 4   II (Paddle)           75
#
#                                                                    Medium  \
# 0                               Refer to FDA's Dissolution Guidance, 2018
# 1  0.01 M Phosphate Buffer with 0.5% sodium dodecyl sulfate (SDS), pH 6.8
# 2                        0.01 M Phosphate Buffer with 0.5 mM EDTA, pH 6.8
# 3                                                               0.1 N HCl
# 4                                                               0.1 N HCl
#
#                                  Volume (mL)  \
# 0                                        NaN
# 1                                        900
# 2                                        500
# 3                                        900
# 4  Acid Stage: 900 mL; Buffer Stage: 1000 mL
#
#                                                  Recommended Sampling Times (minutes)  \
# 0                                                                                 NaN
# 1  Abacavir and lamivudine: 10, 15, 20, 30 and 45; Dolutegravir: 5,15, 25, 35 and 45.
# 2                                                            5, 10, 15, 30, 45 and 60
# 3                                                                 10, 20, 30, and 45
# 4                                                                5, 10, 15, 30 and 45
#
#   Date Updated
# 0   07/02/2020
# 1   05/28/2015
# 2   10/06/2023
# 3   01/03/2007
# 4   01/03/2007

# %% [markdown]
# Establishing known lists for reference in clean up.

# %%
# Known "Dosage Form" release types to help detect them outside parentheses
KNOWN_RELEASE_TYPES = [
    "Extended Release", "Delayed Release", "Orally Disintegrating", 
    "Immediate Release", "Controlled Release", "Sustained Release", 
    "Copackage" # , "For Suspension"
]

# Known RPM units
RPM_UNIT_MAP = {
    "rpm": "RPM",
    "cycles per min": "RPM",
    "cycles (chews) per minute": "RPM",
    "dpm": "DPM",
    "dips/min": "DPM",
    "dpm (dip rate per minute)": "DPM",
    "cycles per min": "cycles/min",
    "cycles/min": "cycles/min"
}

# %% [markdown]
# Defining cleanup functions.

# %%
# Defining function to cleanup "Dosage Form" data
def clean_dosage_form(value):
    if pd.isna(value):
        return ("Unknown", "Unknown")
    
    # Strip spaces
    val = str(value).strip()

    # # Look for release type in parentheses
    # m = re.match(r"^(.*?)\s*\((.*?)\)$", val)
    
    # Regex: capture base form + anything inside parentheses
    # e.g. "Tablet (Delayed Release, Orally Disintegrating)"
    m = re.match(r"^(.*?)\s*(?:\((.+)\))?$", val)
    # m = re.match(r"^([A-Za-z ]+?)(?:\s*\((.+)\))?$", val)
    if m:
        dosage_form = m.group(1).strip().title()  # normalize dosage form
        release_type = m.group(2).strip() if m.group(2) else None

        # Remove trailing commas from both
        dosage_form = dosage_form.rstrip(',').strip()
        dosage_form = re.sub(r"\s+", " ", dosage_form)
        if release_type:
            release_type = release_type.rstrip(',').strip() # Note: ODT refers to Orally Disintegrating Tablet
            release_type = re.sub(r"\s+", " ", release_type)
            if release_type and not release_type[0].isupper():
                release_type = release_type[0].upper() + release_type[1:]

        # If no parentheses captured and there’s a comma, check for trailing release type
        if not release_type and ',' in dosage_form:
            parts = [p.strip() for p in dosage_form.split(',')]
            # If last part looks like a known release type, separate it
            if parts[-1] in KNOWN_RELEASE_TYPES:
                release_type = parts[-1]
                dosage_form = ', '.join(parts[:-1]).rstrip(',').strip()
        
        return dosage_form, release_type
    else:
        # fallback: keep whole thing in base, no modifiers
        return val.rstrip(',').title(), None


# • Apparatus → categorical → one-hot encode
# • Medium type → categorical → one-hot encode
# • RPM → numerical
# • Medium volume → numerical
# • Sampling times → numerical summary features (e.g., # of samples, max time)

# Defining function to cleanup "USP Apparatus" data

# def clean_usp_apparatus(value):
#     if pd.isna(value):
#         return "Unknown"
    
#     # Strip spaces
#     val = str(value).strip().title()

#     # Normalize common names
#     val = re.sub(r"\b(USP|Apparatus|Dissolution)\b", "", val)

#     # Remove extra whitespace
#     val = re.sub(r"\s+", " ", val).strip()

#     return val if val else "Unknown"

# • Apparatus → categorical → one-hot encode
# • Medium type → categorical → one-hot encode
# • RPM → numerical
# • Medium volume → numerical
# • Sampling times → numerical summary features (e.g., # of samples, max time)


# Preparing for cleanup of "Speed (RPMs)" data
df.rename(columns={"Speed (RPMs)": "Speed (RPMs) (Raw)"}, inplace=True)


# # Defining function to cleanup "Speed (RPMs)" data
# def clean_speed_rpms(value):
#     if pd.isna(value):
#         return 0

#     # Extract numeric part
#     val = re.findall(r"[\d.]+", str(value))
#     return float(val[0]) if val else 0

# Defining function to cleanup "Medium" data

# Defining function to cleanup "Volume (mL)" data

# Defining function to cleanup "Recommended Sampling Times (minutes)" data

# %%
# df["Speed (RPMs) (Raw)"].value_counts().reset_index(name="count").rename(columns={"index": "Speed (RPMs) (Raw)"})
num_unique_rpms = len(df["Speed (RPMs) (Raw)"].value_counts())
print("Number of rows displayed:", num_unique_rpms)

# df["Speed (RPMs) (Raw)"].value_counts().to_frame().style.set_table_attributes('style="display:inline"').set_table_styles(
#     [{'selector': 'table', 'props': [('max-height', '400px'), ('overflow-y', 'scroll'), ('display', 'block')]}]
# )
# Out:
# Number of rows displayed: 63

# %%
# Replacing any Unicode non-breaking space characters ("\xa0") with spaces
val = str(df["Speed (RPMs) (Raw)"]).replace("\xa0", " ").strip()
results = []

# Split by semicolons for multiple measurements
parts = [p.strip() for p in val.split(";")]

# Define regex patterns to explore
regex_patterns = {
    "digits_only": r'^\d+$',               # pure digits only
    "rpm_values": r'^\d+\s?RPM$',          # e.g., '50 RPM'
    "dpm_values": r'^\d+\s?DPM$',          # e.g., '30 DPM'
    "unclear_values": r'(\d+)\s*([A-Za-z/ ]+)',
    "embedded_cycles": r'(\d+)\s*(rpm|dpm|cycles per min|cycles/min)',
    "drug_based": r'([\d, andmgMG ]+):\s*(\d+)\s*([A-Za-z/]+)?',
    "other": r'(.+?):\s*(\d+)\s*([A-Za-z/]+)?',
}

# Function to match each semicolon-separated part
def match_parts(entry, pattern):
    entry = str(entry).replace("\xa0", " ").strip()
    parts = [p.strip() for p in entry.split(";")]
    matched_parts = [p for p in parts if pattern.match(p)]
    return matched_parts if matched_parts else [None]

# Choose a pattern to display (change this key as needed)
selected_pattern_key = "embedded_cycles"
selected_pattern = regex_patterns[selected_pattern_key]

# Compile regex
pattern = re.compile(selected_pattern, flags=re.IGNORECASE)

# Filter rows that MATCH this pattern
mask = df["Speed (RPMs) (Raw)"].astype(str).str.match(pattern)

# Compute value counts DataFrame
vc = df.loc[mask, "Speed (RPMs) (Raw)"].value_counts().to_frame(name="count")

# Count how many rows will be displayed
row_count = len(vc)
print(f"Number of rows displayed for pattern '{selected_pattern_key}': {row_count}")

# Apply styling for display in Jupyter
filtered = (
    vc.style
    .set_table_attributes('style="display:inline"')
    .set_table_styles(
        [{'selector': 'table',
          'props': [('max-height', '400px'),
                    ('overflow-y', 'scroll'),
                    ('display', 'block')]}]
    )
)

filtered
# Out:
# Number of rows displayed for pattern 'embedded_cycles': 9
# <style type="text/css">
# #T_76f6c table {
#   max-height: 400px;
#   overflow-y: scroll;
#   display: block;
# }
# </style>
# <table id="T_76f6c" style="display:inline">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76f6c_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Speed (RPMs) (Raw)</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76f6c_level0_row0" class="row_heading level0 row0" >20 dpm</th>
#       <td id="T_76f6c_row0_col0" class="data row0 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_76f6c_level0_row1" class="row_heading level0 row1" >27 dpm</th>
#       <td id="T_76f6c_row1_col0" class="data row1 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_76f6c_level0_row2" class="row_heading level0 row2" >50 RPM (12.5 mg, 25 mg and 100 mg); 75 RPM (150 mg and 200 mg)</th>
#       <td id="T_76f6c_row2_col0" class="data row2 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_76f6c_level0_row3" class="row_heading level0 row3" >75 rpm (for 75 mg strength); 150 rpm (for 300 mg strength)</th>
#       <td id="T_76f6c_row3_col0" class="data row3 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_76f6c_level0_row4" class="row_heading level0 row4" >25 dpm</th>
#       <td id="T_76f6c_row4_col0" class="data row4 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_76f6c_level0_row5" class="row_heading level0 row5" >30 cycles per min </th>
#       <td id="T_76f6c_row5_col0" class="data row5 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_76f6c_level0_row6" class="row_heading level0 row6" >12 dpm</th>
#       <td id="T_76f6c_row6_col0" class="data row6 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_76f6c_level0_row7" class="row_heading level0 row7" >30 cycles per minute. amplitude of  about 2m.</th>
#       <td id="T_76f6c_row7_col0" class="data row7 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_76f6c_level0_row8" class="row_heading level0 row8" >10 dpm (dip rate per minute)</th>
#       <td id="T_76f6c_row8_col0" class="data row8 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
unique_rpm_values = pd.DataFrame(df["Speed (RPMs) (Raw)"].unique(), columns=["Unique RPMs"])

# Force display of all rows in this DataFrame
with pd.option_context("display.max_rows", None):
    display(unique_rpm_values)
# Out:
#                                                        Unique RPMs
# 0                                                              NaN
# 1                                                               85
# 2                                                               50
# 3                                                               75
# 4                                                               55
# 5                                                              180
# 6                                                              100
# 7                                                               60
# 8                                Clarithromycin and Vonoprazan: 50
# 9                                                   Vonoprazan: 50
# 10                                                        4 mL/min
# 11                                                              25
# 12                                                             150
# 13                                                 Flow @ 8 mL/min
# 14                                                              70
# 15                                                              20
# 16                                            20 (CABO); 50 (RILP)
# 17                                               Met: 100: Can:100
# 18                                Canagliflozin: 75; Metformin: 50
# 19                                                             75
# 20                     Carbidopa and Levodopa: 50; Entacapone: 125
# 21                50 mg, 100 mg and 200 mg: 50 rpm; 400 mg: 75 rpm
# 22                                                          27 dpm
# 23                                                 Flow @ 6 mL/min
# 24  50 RPM (12.5 mg, 25 mg and 100 mg); 75 RPM (150 mg and 200 mg)
# 25                                                Cobi: 75; Drv:75
# 26      75 rpm (for 75 mg strength); 150 rpm (for 300 mg strength)
# 27                                                              65
# 28                                                          25 dpm
# 29                                              30 cycles per min
# 30                                                          12 dpm
# 31                                                     100 (diclo)
# 32                                Dutasteride: 75   Tamsulosin: 50
# 33                                                   Elagolix: 100
# 34                            FDC: ELE: 75/IVA: 65/TEZ:75; IVA: 75
# 35                               Acid stage: 100; Buffer stage: 75
# 36                                                             130
# 37                                                     30 dips/min
# 38                                                              40
# 39                                                       25 and 50
# 40                   30 cycles per minute. amplitude of  about 2m.
# 41                                                             175
# 42                   Swirl orbit of 50 mm at 205 rpm for 6 seconds
# 43              Hydrochlorothiazide: 100; Metoprolol succinate: 75
# 44                                    Lumacaftor:65; Ivacaftor: 65
# 45                                    FDC: IVA: 65/TEZ:75; IVA: 65
# 46                                   Lamivudine and Zidovudine: 75
# 47                                    10 dpm (dip rate per minute)
# 48                                                RIB: 50; LET: 75
# 49                                                     15 dips/min
# 50                                                Mel: 75; Riz: 50
# 51                             75 (for 500 mg) & 125 (for 1000 mg)
# 52                          Phase 1 & 2: 100 rpm;  Phase 3: 50 rpm
# 53                           Naproxen::50 rpm Esomeprazole::75 rpm
# 54                               Netupitant:100;  Palonosetron: 75
# 55                                    60 cycles (chews) per minute
# 56                                                          20 dpm
# 57                                                 Flow @ 3 mL/min
# 58                                                              35
# 59                                                             200
# 60                        Acid Stage: 75 rpm; Buffer Stage: 60 rpm
# 61                                                            100
# 62                   Stroke depth: 2-3 cm; 30-60 cycles per minute
# 63                                                              30

# %%
# import re
# import pandas as pd

# def clean_speed(value):
#     if pd.isna(value):
#         return (None, None, None)  # Speed, Unit, Notes
    
#     val = str(value).strip().replace("\xa0", " ")  # clean NBSP
    
#     # Match simple RPM number
#     if re.fullmatch(r"\d+", val):
#         return (int(val), "RPM", None)
    
#     # Check for "dpm", "cycles per min", "dips/min", "mL/min"
#     units_map = {
#         "dpm": r"(\d+)\s*dpm",
#         "cycles/min": r"(\d+)\s*cycles(?:\s*\(.*\))?\s*per\s*min(?:ute)?",
#         "dips/min": r"(\d+)\s*dips?/min",
#         "mL/min": r"(\d+)\s*mL/min",
#         "RPM": r"(\d+)\s*rpm",
#     }
    
#     for unit, pattern in units_map.items():
#         m = re.search(pattern, val, flags=re.I)
#         if m:
#             return (int(m.group(1)), unit, val)  # keep full text as notes
    
#     # Fallback: return None for speed but preserve text as Notes
#     return (None, None, val)

# # Apply to DataFrame
# df[["Speed (RPMs) (Clean)", "Speed Unit", "Speed Notes"]] = df["Speed (RPMs) (Raw)"].apply(
#     lambda x: pd.Series(clean_speed(x))
# )

# df[df["Speed (RPMs) (Raw)"] == "50 RPM (12.5 mg, 25 mg and 100 mg); 75 RPM (150 mg and 200 mg)"]

# %%
# Define globally
rpm_case_tracking_dict = {
    "Case: empty entry": 0,
    "Case: pure number": 0,
    "Case: number + unit": 0,
    "Case: number with unit embedded": 0,
    "Case: \"X mg, Y mg and Z mg: N rpm\"": 0,
    "Case: \"<Note>: <number> [unit?]\"": 0,
    "Fallback: keep as note": 0,
}

# Setting for which cases to print
rpm_case_printing_dict = {
    "Case: empty entry": False,
    "Case: pure number": False,
    "Case: number + unit": True,
    "Case: number with unit embedded": True,
    "Case: \"X mg, Y mg and Z mg: N rpm\"": True,
    "Case: \"<Note>: <number> [unit?]\"": True,
    "Fallback: keep as note": True,
}

def clean_speed_entry(entry):
    """
    Returns a list of tuples: (Speed, Unit, Notes)
    Handles multiple numbers per entry and colon/semicolon-separated cases.
    """
    if pd.isna(entry):
        rpm_case_tracking_dict["Case: empty entry"] += 1
        if rpm_case_printing_dict["Case: empty entry"] == True:
            print("Case: empty entry                    ", (None, None, None))
        return [(None, None, None)]

    # Replacing any Unicode non-breaking space characters ("\xa0") with spaces
    # val = str(entry).replace("\xa0", " ").strip()
    
    # Replace non-breaking spaces and collapse all whitespace in one go
    val = re.sub(r'\s+', ' ', str(entry).replace("\xa0", " ")).strip()

    results = []

    # Split by semicolons for multiple measurements
    parts = [p.strip() for p in val.split(";")]

    for part in parts:
        # Case: pure number
        if part.isdigit():
            results.append((int(part), "RPM", None))
            rpm_case_tracking_dict["Case: pure number"] += 1
            if rpm_case_printing_dict["Case: pure number"] == True:
                print("Case: pure number                    ", (int(part), "RPM", None))
            continue

        # Case: number + unit
        match = re.match(r"(\d+)\s*([A-Za-z/ ]+)", part)
        if match and match.group(2) != '':
            speed = int(match.group(1))
            unit = match.group(2).strip().replace("per minute", "/min")
            results.append((speed, unit, None))
            rpm_case_tracking_dict["Case: number + unit"] += 1
            if rpm_case_printing_dict["Case: number + unit"] == True:
                print("Case: number + unit                  ", (speed, unit, None))
            if unit == "":
                print("Problematic row:")
                display(df[df["Speed (RPMs) (Raw)"] == entry].head())
            continue

        # Case: number with unit embedded
        embedded = re.search(r"(\d+)\s*(rpm|dpm|cycles per min|cycles/min)", part, flags=re.I)
        if embedded:
            speed = int(embedded.group(1))
            unit = RPM_UNIT_MAP.get(embedded.group(2).lower(), embedded.group(2).upper())
            # Remove speed/unit from note
            note = re.sub(r"\d+\s*" + embedded.group(2), "", part, flags=re.I).strip(",; ")
            results.append((speed, unit, note if note else None))
            rpm_case_tracking_dict["Case: number with unit embedded"] += 1
            if rpm_case_printing_dict["Case: number with unit embedded"] == True:
                print("Case: number with unit embedded")
            continue
            
        # Case: "X mg, Y mg and Z mg: N rpm"
        multi_match = re.match(r"([\d, andmgMG ]+):\s*(\d+)\s*([A-Za-z/]+)?", part)
        if multi_match:
            drugs = re.split(r",|and", multi_match.group(1))
            speed = int(multi_match.group(2))
            unit = multi_match.group(3).lower() if multi_match.group(3) else "rpm"
            unit = RPM_UNIT_MAP.get(unit.lower(), unit.upper())
            for d in [d.strip() for d in drugs if d.strip()]:
                results.append((speed, unit, d))
            rpm_case_tracking_dict["Case: \"X mg, Y mg and Z mg: N rpm\""] += 1
            if rpm_case_printing_dict["Case: \"X mg, Y mg and Z mg: N rpm\""] == True:
                print("Case: \"X mg, Y mg and Z mg: N rpm\"")
            continue

        # Case: "<Note>: <number> [unit?]"
        colon_match = re.match(r"(.+?):\s*(\d+)\s*([A-Za-z/]+)?", part)
        if colon_match:
            note = colon_match.group(1).strip()
            speed = int(colon_match.group(2))
            unit = colon_match.group(3).lower() if colon_match.group(3) else None
            if unit:
                unit = RPM_UNIT_MAP.get(unit.lower(), unit.upper())
            results.append((speed, unit, note))
            rpm_case_tracking_dict["Case: \"<Note>: <number> [unit?]\""] += 1
            if rpm_case_printing_dict["Case: \"<Note>: <number> [unit?]\""] == True:
                print("Case: \"<Note>: <number> [unit?]\"")
            continue

        # Fallback: keep as note
        results.append((None, None, part))
        rpm_case_tracking_dict["Fallback: keep as note"] += 1
        if rpm_case_printing_dict["Fallback: keep as note"] == True:
            print("Fallback: keep as note               ", (None, None, part))
            
    return results

# Apply and expand, safely overwriting existing columns
expanded_rows = df["Speed (RPMs) (Raw)"].apply(clean_speed_entry)
df_cleaned = pd.DataFrame(
    [t for sublist in expanded_rows for t in sublist],
    columns=["Speed (RPMs) (Clean)", "Unit", "Notes"]
)

# Overwrite the old columns safely
df[["Speed (RPMs) (Clean)", "Unit", "Notes"]] = df_cleaned

pd.DataFrame(list(rpm_case_tracking_dict.items()), columns=["Case", "Count"])

# df[df["Speed (RPMs) (Raw)"] == "50 RPM (12.5 mg, 25 mg and 100 mg); 75 RPM (150 mg and 200 mg)"]
df[-200:]
# Out:
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: number + unit                   (4, 'mL/min', None)
# Fallback: keep as note                (None, None, 'Flow @ 8 mL/min')
# Case: number + unit                   (20, '', None)
# Problematic row:
#                                    Drug Name                   Dosage Form  \
# 237  Cabotegravir (CABO); Rilpivirine (RILP)  Suspension, Extended release
#
#     USP Apparatus    Speed (RPMs) (Raw)  \
# 237   II (Paddle)  20 (CABO); 50 (RILP)
#
#                                                                                                                                                                              Medium  \
# 237  0.5% w/v solution of cetyltrimethylammonium bromide (CTAB) in 140 mM McIlvaine buffer, pH 7.4 (CABO); 6.0% w/v Polysorbate 20 in 0.05 M Sodium Phosphate buffer, pH 7.4 (RILP)
#
#     Volume (mL)  \
# 237         NaN
#
#                               Recommended Sampling Times (minutes)  \
# 237  5, 10, 15, 20, 30, 45 and 60 (CABO); 5, 30, 90 and 360 (RILP)
#
#     Date Updated  Speed (RPMs) (Clean) Unit Notes Dosage Form (Clean)  \
# 237   05/18/2023                  20.0       None          Suspension
#
#          Release Type
# 237  Extended Release
# Case: number + unit                   (50, '', None)
# Problematic row:
#                                    Drug Name                   Dosage Form  \
# 237  Cabotegravir (CABO); Rilpivirine (RILP)  Suspension, Extended release
#
#     USP Apparatus    Speed (RPMs) (Raw)  \
# 237   II (Paddle)  20 (CABO); 50 (RILP)
#
#                                                                                                                                                                              Medium  \
# 237  0.5% w/v solution of cetyltrimethylammonium bromide (CTAB) in 140 mM McIlvaine buffer, pH 7.4 (CABO); 6.0% w/v Polysorbate 20 in 0.05 M Sodium Phosphate buffer, pH 7.4 (RILP)
#
#     Volume (mL)  \
# 237         NaN
#
#                               Recommended Sampling Times (minutes)  \
# 237  5, 10, 15, 20, 30, 45 and 60 (CABO); 5, 30, 90 and 360 (RILP)
#
#     Date Updated  Speed (RPMs) (Clean) Unit Notes Dosage Form (Clean)  \
# 237   05/18/2023                  20.0       None          Suspension
#
#          Release Type
# 237  Extended Release
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: number + unit                   (50, 'mg', None)
# Case: number + unit                   (400, 'mg', None)
# Case: number + unit                   (27, 'dpm', None)
# Fallback: keep as note                (None, None, 'Flow @ 6 mL/min')
# Case: number + unit                   (50, 'RPM', None)
# Case: number + unit                   (75, 'RPM', None)
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: number + unit                   (75, 'rpm', None)
# Case: number + unit                   (150, 'rpm', None)
# Case: number + unit                   (25, 'dpm', None)
# Case: number + unit                   (30, 'cycles per min', None)
# Case: number + unit                   (12, 'dpm', None)
# Case: number + unit                   (100, '', None)
# Problematic row:
#                                         Drug Name               Dosage Form  \
# 460  Diclofenac Sodium/Misoprostol Enteric Coated  Tablet (Delayed Release)
#
#            USP Apparatus Speed (RPMs) (Raw)  \
# 460  II (Paddle) (diclo)        100 (diclo)
#
#                                                                                                                                                   Medium  \
# 460  Diclofenac: Acid Stage: 0.1 N HCl  Buffer Stage: 750ml 0.1N HCL+250ml 0.2M phos.buffer, pH 6.8 (Method A) Misoprostol: Develop a dissolution method
#
#                       Volume (mL)  \
# 460  Diclo: Acid: 750 Buffer:1000
#
#               Recommended Sampling Times (minutes) Date Updated  \
# 460  Diclo.: 120 (acid) 15, 30, 45 and 60 (Buffer)   09/15/2023
#
#      Speed (RPMs) (Clean) Unit Notes Dosage Form (Clean)     Release Type
# 460                 100.0  RPM  None              Tablet  Delayed Release
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: number + unit                   (30, 'dips/min', None)
# Case: number + unit                   (25, 'and', None)
# Case: number + unit                   (30, 'cycles /min', None)
# Case: number with unit embedded
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: number + unit                   (10, 'dpm', None)
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: number + unit                   (15, 'dips/min', None)
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: number + unit                   (75, '', None)
# Problematic row:
#       Drug Name  Dosage Form                            USP Apparatus  \
# 949  Mesalamine  Suppository  II (Paddle) with option to use a sinker
#
#                       Speed (RPMs) (Raw)  \
# 949  75 (for 500 mg) & 125 (for 1000 mg)
#
#                                                                                                                                  Medium  \
# 949  For 500 mg strength: 0.2 M Phosphate buffer, pH 7.5 at 37 deg. C For 1000 mg strength: 0.2 M Phosphate buffer, pH 7.5 at 40 deg. C
#
#     Volume (mL) Recommended Sampling Times (minutes) Date Updated  \
# 949         900              30, 60, 90, 120 and 150   01/30/2006
#
#      Speed (RPMs) (Clean)  Unit Notes Dosage Form (Clean) Release Type
# 949                   NaN  None  None         Suppository         None
# Case: number with unit embedded
# Case: number with unit embedded
# Case: number with unit embedded
# Case: "<Note>: <number> [unit?]"
# Case: "<Note>: <number> [unit?]"
# Case: number + unit                   (60, 'cycles', None)
# Case: number + unit                   (20, 'dpm', None)
# Fallback: keep as note                (None, None, 'Flow @ 3 mL/min')
# Case: number with unit embedded
# Case: number with unit embedded
# Case: "<Note>: <number> [unit?]"
# Case: number with unit embedded
# Case: number + unit                   (20, 'dpm', None)
#                                                                       Drug Name  \
# 1368                                                                  Silodosin
# 1369                                                          Simeprevir Sodium
# 1370                                                                Simvastatin
# 1371                                                                Simvastatin
# 1372                                                                Simvastatin
# 1373                                                     Siponimod Fumaric Acid
# 1374                                                                  Sirolimus
# 1375                                                                  Sirolimus
# 1376                                                      Sitagliptin Phosphate
# 1377                                          Sitagliptin Phosphate/Simvastatin
# 1378                                                        Sodium Iodide I-123
# 1379                                                        Sodium Iodide I-131
# 1380                                                             Sodium Oxybate
# 1381                                                      Sodium Phenylbutyrate
# 1382                                                      Sodium Phenylbutyrate
# 1383                                        Sodium Phenylbutyrate; Taurursodiol
# 1384  Sodium Phosphate Dibasic Anhydrous/Sodium Phosphate Monobasic Monohydrate
# 1385                                                                 Sofosbuvir
# 1386                                                                 Sofosbuvir
# 1387                                                     Sofosbuvir/Velpatasvir
# 1388                                                      Solifenacin Succinate
# 1389                                                      Solifenacin Succinate
# 1390                                                           Solriamfetol HCl
# 1391                                                        Sonidegib Phosphate
# 1392                                                         Sorafenib Tosylate
# 1393                                                              Sotagliflozin
# 1394                                                                  Sotorasib
# 1395                                                                 Sparsentan
# 1396                                                             Spironolactone
# 1397                                                                  Stavudine
# 1398                                                                   Succimer
# 1399                                                                 Sucralfate
# 1400                                                                 Sucralfate
# 1401                                                   Sucroferric Oxyhydroxide
# 1402                                                         Sufentanil Citrate
# 1403                                                               Sulfadiazine
# 1404                                              Sulfamethoxazole/Trimethoprim
# 1405                                              Sulfamethoxazole/Trimethoprim
# 1406                                                              Sulfasalazine
# 1407                                                              Sulfasalazine
# 1408                                                       Sulfisoxazole Acetyl
# 1409                                                      Sumatriptan Succinate
# 1410                                                           Sunitinib Malate
# 1411                                                                 Suvorexant
# 1412                                                                 Tacrolimus
# 1413                                                                 Tacrolimus
# 1414                                                                 Tacrolimus
# 1415                                                                  Tadalafil
# 1416                                                                  Tafamidis
# 1417                                                        Tafamidis Meglumine
# 1418                                                      Tafenoquine Succinate
# 1419                                                       Talazoparib Tosylate
# 1420                                                          Tamoxifen Citrate
# 1421                                                             Tamsulosin HCl
# 1422                                                             Tapentadol HCl
# 1423                                                             Tapentadol HCl
# 1424                                                                Tasimelteon
# 1425                                                                Tasimelteon
# 1426                                                  Tazemetostat Hydrobromide
# 1427                                                        Tedizolid Phosphate
# 1428                                                          Tegaserod Maleate
# 1429                                                                 Telaprevir
# 1430                                                                Telbivudine
# 1431                                                              Telithromycin
# 1432                                                                Telmisartan
# 1433                                                                  Temazepam
# 1434                                                               Temozolomide
# 1435                                                    Tenapanor Hydrochloride
# 1436                                             Tenofovir Alafenamide Fumarate
# 1437                                              Tenofovir Disoproxil Fumarate
# 1438                                              Tenofovir Disoproxil Fumarate
# 1439                                                              Tepotinib HCl
# 1440                                                              Terazosin HCl
# 1441                                                              Terazosin HCl
# 1442                                                            Terbinafine HCl
# 1443                                                                Terconazole
# 1444                                                              Teriflunomide
# 1445                                                               Testosterone
# 1446                                                               Testosterone
# 1447                                                               Testosterone
# 1448                                                   Testosterone Undecanoate
# 1449                                                   Testosterone Undecanoate
# 1450                                                              Tetrabenazine
# 1451                                                           Tetracycline HCl
# 1452                                                           Tetracycline HCl
# 1453                                                                Thalidomide
# 1454                                                               Theophylline
# 1455                                           Theophylline (100 mg and 200 mg)
# 1456                                           Theophylline (300 mg and 450 mg)
# 1457                                           Theophylline (600 mg and 400 mg)
# 1458                                                                Thioguanine
# 1459                                                              Tiagabine HCl
# 1460                                                                 Ticagrelor
# 1461                                                            Ticlopidine HCl
# 1462                                                            Timolol Maleate
# 1463                                                                 Tinidazole
# 1464                                                                  Tiopronin
# 1465                                                                  Tiopronin
# 1466                                                 Tipiracil HCl/Trifluridine
# 1467                                                                 Tipranavir
# 1468                                                              Tivozanib HCl
# 1469                                                             Tizanidine HCl
# 1470                                                             Tizanidine HCl
# 1471                                                        Tofacitinib Citrate
# 1472                                                        Tofacitinib Citrate
# 1473                                                                  Tolcapone
# 1474                                                       Tolterodine Tartrate
# 1475                                                       Tolterodine Tartrate
# 1476                                                                  Tolvaptan
# 1477                                                                 Topiramate
# 1478                                                                 Topiramate
# 1479                               Topiramate  [25, 50, 100, 150 mg and 200 mg]
# 1480                                        Topiramate [25, 50, 100 and 200 mg]
# 1481                                                              Topotecan HCl
# 1482                                                         Toremifene Citrate
# 1483                                                                  Torsemide
# 1484                                               Torsemide [20, 40 and 60 mg]
# 1485                                                                   Tramadol
# 1486                                                               Tramadol HCl
# 1487                                                               Tramadol HCl
# 1488                                              Trametinib Dimethyl Sulfoxide
# 1489                                                               Trandolapril
# 1490                                                 Trandolapril/Verapamil HCl
# 1491                                                            Tranexamic Acid
# 1492                                                    Tranylcypromine Sulfate
# 1493                                                              Trazodone HCl
# 1494                                                              Trazodone HCl
# 1495                                                     Treprostinil Diolamine
# 1496                                                                  Tretinoin
# 1497                                                    Triamcinolone Acetonide
# 1498                                                    Triamcinolone Acetonide
# 1499                                                            Triclabendazole
# 1500                                                              Trientine HCl
# 1501                                                               Trimethoprim
# 1502                                                       Trimipramine Maleate
# 1503                                                        Triptorelin Pamoate
# 1504                                                        Triptorelin Pamoate
# 1505                                                          Trospium Chloride
# 1506                                                          Trospium Chloride
# 1507                                                                  Tucatinib
# 1508                                                         Ulipristal Acetate
# 1509                                                               Upadacitinib
# 1510                                                         Uridine Triacetate
# 1511                                                                   Ursodiol
# 1512                                                                   Ursodiol
# 1513                                                 Valacyclovir Hydrochloride
# 1514                                                                Valbenazine
# 1515                                                                Valbenazine
# 1516                                                         Valganciclovir HCl
# 1517                                                              Valproic Acid
# 1518                                                                  Valsartan
# 1519                                                                  Valsartan
# 1520                                                                 Vamorolone
# 1521                                                   Vancomycin hydrochloride
# 1522                                                                 Vandetanib
# 1523                                                             Vardenafil HCl
# 1524                                                             Vardenafil HCl
# 1525                                                       Varenicline Tartrate
# 1526                                                                Vemurafenib
# 1527                                                                 Venetoclax
# 1528                                                       Venlafaxine Besylate
# 1529                                                            Venlafaxine HCl
# 1530                                                            Venlafaxine HCl
# 1531                                                            Venlafaxine HCl
# 1532                                                              Verapamil HCl
# 1533                                                              Verapamil HCl
# 1534                                                              Verapamil HCl
# 1535                                                                 Vericiguat
# 1536                                                                Verteporfin
# 1537                                                                   Vibegron
# 1538                                                                 Vigabatrin
# 1539                                                             Vilazodone HCl
# 1540                                                             Viloxazine HCl
# 1541                                                                 Vismodegib
# 1542                                                                Voclosporin
# 1543                                                          Vorapaxar Sulfate
# 1544                                                               Voriconazole
# 1545                                                               Voriconazole
# 1546                                                                 Vorinostat
# 1547                                                           Vortioxetine HBr
# 1548                                                                  Voxelotor
# 1549                                                                  Voxelotor
# 1550                                                            Warfarin Sodium
# 1551                                                                Zafirlukast
# 1552                                                                Zalcitabine
# 1553                                                                   Zaleplon
# 1554                                                                 Zidovudine
# 1555                                                                   Zileuton
# 1556                                                                   Zileuton
# 1557                                                               Zinc Acetate
# 1558                                                            Ziprasidone HCl
# 1559                                                               Zolmitriptan
# 1560                                                               Zolmitriptan
# 1561                                                          Zolpidem Tartrate
# 1562                                                          Zolpidem Tartrate
# 1563                                        Zolpidem Tartrate (1.75 and 3.5 mg)
# 1564                                            Zolpidem Tartrate (5 and 10 mg)
# 1565                                                                 Zonisamide
# 1566                                                                 Zonisamide
# 1567                                                                 Zuranolone
#
#                                              Dosage Form  \
# 1368                                             Capsule
# 1369                                             Capsule
# 1370                                          Suspension
# 1371                                              Tablet
# 1372                      Tablet (Orally Disintegrating)
# 1373                                              Tablet
# 1374                                                 Gel
# 1375                                              Tablet
# 1376                                              Tablet
# 1377                                              Tablet
# 1378                                             Capsule
# 1379                                             Capsule
# 1380                   For Suspension (Extended Release)
# 1381                                             Pellets
# 1382                                     Powder for Oral
# 1383                                              Powder
# 1384                                              Tablet
# 1385                                             Pellets
# 1386                                              Tablet
# 1387                                              Tablet
# 1388                                          Suspension
# 1389                                              Tablet
# 1390                                              Tablet
# 1391                                            Capsule
# 1392                                              Tablet
# 1393                                              Tablet
# 1394                                              Tablet
# 1395                                              Tablet
# 1396                                              Tablet
# 1397                                             Capsule
# 1398                                             Capsule
# 1399                                          Suspension
# 1400                                              Tablet
# 1401                                   Tablet (Chewable)
# 1402                                 Tablet (Sublingual)
# 1403                                              Tablet
# 1404                                              Tablet
# 1405                                          Suspension
# 1406                                              Tablet
# 1407                           Tablet (Delayed Release)
# 1408                         Oral Suspension (Pediatric)
# 1409                                              Tablet
# 1410                                             Capsule
# 1411                                              Tablet
# 1412                                      For Suspension
# 1413                         Tablet (Extended Release)
# 1414                                             Capsule
# 1415                                              Tablet
# 1416                                             Capsule
# 1417                                             Capsule
# 1418                                              Tablet
# 1419                                             Capsule
# 1420                                              Tablet
# 1421                                             Capsule
# 1422                                              Tablet
# 1423                          Tablet (Extended Release)
# 1424                                             Capsule
# 1425                                          Suspension
# 1426                                              Tablet
# 1427                                              Tablet
# 1428                                              Tablet
# 1429                                              Tablet
# 1430                                              Tablet
# 1431                                              Tablet
# 1432                                             Tablet
# 1433                                             Capsule
# 1434                                             Capsule
# 1435                                              Tablet
# 1436                                             Tablet
# 1437                                    Powder for Oral
# 1438                                              Tablet
# 1439                                              Tablet
# 1440                                              Tablet
# 1441                                             Capsule
# 1442                                              Tablet
# 1443                               Suppository (Vaginal)
# 1444                                              Tablet
# 1445               Film, Transdermal (Extended Release)
# 1446                    Buccal Tablet (Extended Release)
# 1447                                      Pellet Implant
# 1448                                             Capsule
# 1449                                             Capsule
# 1450                                              Tablet
# 1451                                              Tablet
# 1452                                             Capsule
# 1453                                             Capsule
# 1454                          Capsule (Extended Release)
# 1455                           Tablet (Extended Release)
# 1456                           Tablet (Extended Release)
# 1457                          Tablet (Extended Release)
# 1458                                              Tablet
# 1459                                              Tablet
# 1460                                              Tablet
# 1461                                              Tablet
# 1462                                              Tablet
# 1463                                              Tablet
# 1464                                             Tablet
# 1465                            Tablet (Delayed Release)
# 1466                                              Tablet
# 1467                                             Capsule
# 1468                                             Capsule
# 1469                                             Capsule
# 1470                                              Tablet
# 1471                                              Tablet
# 1472                          Tablet (Extended  Release)
# 1473                                              Tablet
# 1474                                              Tablet
# 1475                          Capsule (Extended Release)
# 1476                                              Tablet
# 1477                                              Tablet
# 1478                                  Capsule (Sprinkle)
# 1479                          Capsule (Extended Release)
# 1480                          Capsule (Extended Release)
# 1481                                             Capsule
# 1482                                              Tablet
# 1483                                              Tablet
# 1484                                              Tablet
# 1485                          Capsule (Extended Release)
# 1486                           Tablet (Extended Release)
# 1487                                              Tablet
# 1488                                              Tablet
# 1489                                              Tablet
# 1490                           Tablet (Extended Release)
# 1491                                             Tablet
# 1492                                              Tablet
# 1493                          Tablet (Extended Release)
# 1494                                              Tablet
# 1495                          Tablet (Extended Release)
# 1496                                             Capsule
# 1497                              Injectable Suspension
# 1498  Intra-Articular, For Suspension (Extended Release)
# 1499                                              Tablet
# 1500                                             Capsule
# 1501                                              Tablet
# 1502                                             Capsule
# 1503     For Intramuscular Suspension (Extended Release)
# 1504                               Injectable Suspension
# 1505                          Capsule (Extended Release)
# 1506                                              Tablet
# 1507                                              Tablet
# 1508                                              Tablet
# 1509                           Tablet (Extended Release)
# 1510                                             Granule
# 1511                                            Capsules
# 1512                                              Tablet
# 1513                                              Tablet
# 1514                                             Capsule
# 1515                                  Capsule (Sprinkle)
# 1516                                              Tablet
# 1517                                             Capsule
# 1518                                             Tablet
# 1519                                             Capsule
# 1520                                          Suspension
# 1521                                             Capsule
# 1522                                              Tablet
# 1523                                              Tablet
# 1524                     Tablet (Orally Disintegrating)
# 1525                                              Tablet
# 1526                                              Tablet
# 1527                                             Tablet
# 1528                           Tablet (Extended Release)
# 1529                          Capsule (Extended Release)
# 1530                          Tablet (Extended Release)
# 1531                                              Tablet
# 1532                          Capsule (Extended Release)
# 1533                          Tablet (Extended Release)
# 1534                                              Tablet
# 1535                                              Tablet
# 1536                                          Injectable
# 1537                                              Tablet
# 1538                                              Tablet
# 1539                                              Tablet
# 1540                          Capsule (Extended Release)
# 1541                                             Capsule
# 1542                                             Capsule
# 1543                                              Tablet
# 1544                                          Suspension
# 1545                                              Tablet
# 1546                                             Capsule
# 1547                                              Tablet
# 1548                                              Tablet
# 1549                              Tablet, for Suspension
# 1550                                              Tablet
# 1551                                              Tablet
# 1552                                              Tablet
# 1553                                             Capsule
# 1554                                              Tablet
# 1555                         Tablet (Extended Release)
# 1556                                              Tablet
# 1557                                             Capsule
# 1558                                             Capsule
# 1559                      Tablet (Orally Disintegrating)
# 1560                                              Tablet
# 1561                                              Tablet
# 1562                           Tablet (Extended Release)
# 1563                                 Tablet (Sublingual)
# 1564                                 Tablet (Sublingual)
# 1565                                            Capsule
# 1566                                          Suspension
# 1567                                             Capsule
#
#                                                                 USP Apparatus  \
# 1368                                                                      NaN
# 1369                                                              II (Paddle)
# 1370                                                              II (Paddle)
# 1371                                                                      NaN
# 1372                                                              II (Paddle)
# 1373                                                              II (Paddle)
# 1374                                                                      NaN
# 1375                                                                      NaN
# 1376                                                                      NaN
# 1377  II (Paddle) with stainless steel stationary quadrangular hanging basket
# 1378                                                                      NaN
# 1379                                                                      NaN
# 1380                                                              II (Paddle)
# 1381                                                              II (Paddle)
# 1382                                                              II (Paddle)
# 1383                                                              II (Paddle)
# 1384                                                                      NaN
# 1385                                                              II (Paddle)
# 1386                                                              II (Paddle)
# 1387                                                              II (Paddle)
# 1388                                                              II (Paddle)
# 1389                                                                      NaN
# 1390                                                               I (Basket)
# 1391                                                  II (Paddle) with sinker
# 1392                                                              II (Paddle)
# 1393                                                                      NaN
# 1394                                                              II (Paddle)
# 1395                                                              II (Paddle)
# 1396                                                                      NaN
# 1397                                                                      NaN
# 1398                                                              II (Paddle)
# 1399                                                              II (Paddle)
# 1400                                                              II (Paddle)
# 1401                                                              II (Paddle)
# 1402                                                              II (Paddle)
# 1403                                                                      NaN
# 1404                                                                      NaN
# 1405                                                              II (Paddle)
# 1406                                                                      NaN
# 1407                                                                      NaN
# 1408                                                              II (Paddle)
# 1409                                                                      NaN
# 1410                                                                      NaN
# 1411                                                                      NaN
# 1412                                                              II (Paddle)
# 1413                                                              II (Paddle)
# 1414                                                              II (Paddle)
# 1415                                                              II (Paddle)
# 1416                                                  II (Paddle) with sinker
# 1417                                                  II (Paddle) with sinker
# 1418                                                              II (Paddle)
# 1419                                                  II (Paddle) with sinker
# 1420                                                                      NaN
# 1421                                                              II (Paddle)
# 1422                                                                      NaN
# 1423                                                 II (Paddle) with sinker
# 1424                                                                      NaN
# 1425                                                                      NaN
# 1426                                                              II (Paddle)
# 1427                                                             II (Paddle)
# 1428                                                                      NaN
# 1429                                                                      NaN
# 1430                                                              II (Paddle)
# 1431                                                              II (Paddle)
# 1432                                                                      NaN
# 1433                                                                      NaN
# 1434                                                                      NaN
# 1435                                                              II (Paddle)
# 1436                                                                      NaN
# 1437                                                              II (Paddle)
# 1438                                                              II (Paddle)
# 1439                                                              II (Paddle)
# 1440                                                                      NaN
# 1441                                                                      NaN
# 1442                                                              II (Paddle)
# 1443                                            I (with Palmieri type basket)
# 1444                                                             II (Paddle)
# 1445           V (Paddle over disk). Paddle 25 mm above the film on the disk.
# 1446                                                                      NaN
# 1447                                                                      NaN
# 1448                                                              II (Paddle)
# 1449                                                              II (Paddle)
# 1450                                                              II (Paddle)
# 1451                                                                      NaN
# 1452                                                                      NaN
# 1453                                                              II (Paddle)
# 1454                                                                      NaN
# 1455                                                              II (Paddle)
# 1456                                                              II (Paddle)
# 1457                                                               I (Basket)
# 1458                                                                      NaN
# 1459                                                                      NaN
# 1460                                                                      NaN
# 1461                                                                      NaN
# 1462                                                                      NaN
# 1463                                                                      NaN
# 1464                                                                      NaN
# 1465                                                               I (Basket)
# 1466                                                              II (Paddle)
# 1467                                                              II (Paddle)
# 1468                                                  II (Paddle with sinker)
# 1469                                                                      NaN
# 1470                                                                      NaN
# 1471                                                                      NaN
# 1472                                 II (Paddle) with option to use a sinker
# 1473                                                                      NaN
# 1474                                                                      NaN
# 1475                                                               I (Basket)
# 1476                                                                      NaN
# 1477                                                                      NaN
# 1478                                                                      NaN
# 1479                                                               I (Basket)
# 1480                                                              II (Paddle)
# 1481                                                              II (Paddle)
# 1482                                                              II (Paddle)
# 1483                                                              II (Paddle)
# 1484                                                              II (Paddle)
# 1485                                                                      NaN
# 1486                                                               I (Basket)
# 1487                                                                      NaN
# 1488                                                              II (Paddle)
# 1489                                                                      NaN
# 1490                                                              II (Paddle)
# 1491                                                                      NaN
# 1492                                                                      NaN
# 1493                                                                      NaN
# 1494                                                                      NaN
# 1495                                                               I (Basket)
# 1496                                                               I (Basket)
# 1497                                                                      NaN
# 1498                                                              II (Paddle)
# 1499                                                              II (Paddle)
# 1500                                                                      NaN
# 1501                                                                      NaN
# 1502                                                                      NaN
# 1503                                                              II (Paddle)
# 1504                                                              II (Paddle)
# 1505                                                  II (Paddle) with sinker
# 1506                                                                      NaN
# 1507                                                              II (Paddle)
# 1508                                                              II (Paddle)
# 1509                                                               I (Basket)
# 1510                                                              II (Paddle)
# 1511                                                                      NaN
# 1512                                                                      NaN
# 1513                                                                      NaN
# 1514                                                  II (Paddle) with sinker
# 1515                                                               I (Basket)
# 1516                                                                      NaN
# 1517                                                                      NaN
# 1518                                                                      NaN
# 1519                                                              II (Paddle)
# 1520                                                              II (Paddle)
# 1521                                                                      NaN
# 1522                                                              II (Paddle)
# 1523                                                                      NaN
# ...
# 1436                  75.0   RPM  None                           Tablet
# 1437                  75.0   RPM  None                  Powder For Oral
# 1438                   NaN  None  None                           Tablet
# 1439                 100.0   RPM  None                           Tablet
# 1440                   NaN  None  None                           Tablet
# 1441                 100.0   RPM  None                          Capsule
# 1442                   NaN  None  None                           Tablet
# 1443                   NaN  None  None                      Suppository
# 1444                  50.0   RPM  None                           Tablet
# 1445                  60.0   RPM  None                Film, Transdermal
# 1446                   NaN  None  None                    Buccal Tablet
# 1447                   NaN  None  None                   Pellet Implant
# 1448                  50.0   RPM  None                          Capsule
# 1449                  50.0   RPM  None                          Capsule
# 1450                   NaN  None  None                           Tablet
# 1451                   NaN  None  None                           Tablet
# 1452                   NaN  None  None                          Capsule
# 1453                  75.0   RPM  None                          Capsule
# 1454                   NaN  None  None                          Capsule
# 1455                 100.0   RPM  None                           Tablet
# 1456                  50.0   RPM  None                           Tablet
# 1457                  50.0   RPM  None                           Tablet
# 1458                   NaN  None  None                           Tablet
# 1459                   NaN  None  None                           Tablet
# 1460                  50.0   RPM  None                           Tablet
# 1461                 100.0   RPM  None                           Tablet
# 1462                  50.0   RPM  None                           Tablet
# 1463                  50.0   RPM  None                           Tablet
# 1464                   NaN  None  None                           Tablet
# 1465                   NaN  None  None                           Tablet
# 1466                  75.0   RPM  None                           Tablet
# 1467                  75.0   RPM  None                          Capsule
# 1468                  50.0   RPM  None                          Capsule
# 1469                   NaN  None  None                          Capsule
# 1470                   NaN  None  None                           Tablet
# 1471                 100.0   RPM  None                           Tablet
# 1472                   NaN  None  None                           Tablet
# 1473                  50.0   RPM  None                           Tablet
# 1474                  50.0   RPM  None                           Tablet
# 1475                 100.0   RPM  None                          Capsule
# 1476                   NaN  None  None                           Tablet
# 1477                   NaN  None  None                           Tablet
# 1478                   NaN  None  None                          Capsule
# 1479                   NaN  None  None                          Capsule
# 1480                   NaN  None  None                          Capsule
# 1481                   NaN  None  None                          Capsule
# 1482                   NaN  None  None                           Tablet
# 1483                 100.0   RPM  None                           Tablet
# 1484                  50.0   RPM  None                           Tablet
# 1485                  50.0   RPM  None                          Capsule
# 1486                  50.0   RPM  None                           Tablet
# 1487                   NaN  None  None                           Tablet
# 1488                   NaN  None  None                           Tablet
# 1489                   NaN  None  None                           Tablet
# 1490                  50.0   RPM  None                           Tablet
# 1491                   NaN  None  None                           Tablet
# 1492                   NaN  None  None                           Tablet
# 1493                 100.0   RPM  None                           Tablet
# 1494                   NaN  None  None                           Tablet
# 1495                   NaN  None  None                           Tablet
# 1496                   NaN  None  None                          Capsule
# 1497                 100.0   RPM  None            Injectable Suspension
# 1498                  50.0   RPM  None  Intra-Articular, For Suspension
# 1499                  50.0   RPM  None                           Tablet
# 1500                  50.0   RPM  None                          Capsule
# 1501                  50.0   RPM  None                           Tablet
# 1502                  75.0   RPM  None                          Capsule
# 1503                   NaN  None  None     For Intramuscular Suspension
# 1504                  75.0   RPM  None            Injectable Suspension
# 1505                   NaN  None  None                          Capsule
# 1506                  60.0   RPM  None                           Tablet
# 1507                   NaN  None  None                           Tablet
# 1508                  50.0   RPM  None                           Tablet
# 1509                   NaN  None  None                           Tablet
# 1510                   NaN  None  None                          Granule
# 1511                   NaN  None  None                         Capsules
# 1512                   NaN  None  None                           Tablet
# 1513                 100.0   RPM  None                           Tablet
# 1514                 100.0   RPM  None                          Capsule
# 1515                   NaN  None  None                          Capsule
# 1516                  75.0   RPM  None                           Tablet
# 1517                  75.0   RPM  None                          Capsule
# 1518                   NaN  None  None                           Tablet
# 1519                   NaN  None  None                          Capsule
# 1520                   NaN  None  None                       Suspension
# 1521                  75.0   RPM  None                          Capsule
# 1522                 200.0   RPM  None                           Tablet
# 1523                  50.0   RPM  None                           Tablet
# 1524                   NaN  None  None                           Tablet
# 1525                  75.0   RPM  None                           Tablet
# 1526                  50.0   RPM  None                           Tablet
# 1527                 100.0   RPM  None                           Tablet
# 1528                  60.0   RPM  None                           Tablet
# 1529                   NaN  None  None                          Capsule
# 1530                   NaN  None  None                           Tablet
# 1531                   NaN  None  None                           Tablet
# 1532                  50.0   RPM  None                          Capsule
# 1533                  50.0   RPM  None                           Tablet
# 1534                   NaN  None  None                           Tablet
# 1535                   NaN  None  None                           Tablet
# 1536                   NaN  None  None                       Injectable
# 1537                  50.0   RPM  None                           Tablet
# 1538                  75.0   RPM  None                           Tablet
# 1539                   NaN  None  None                           Tablet
# 1540                  50.0   RPM  None                          Capsule
# 1541                   NaN  None  None                          Capsule
# 1542                  50.0   RPM  None                          Capsule
# 1543                   NaN  None  None                           Tablet
# 1544                  75.0   RPM  None                       Suspension
# 1545                  20.0   dpm  None                           Tablet
# 1546                  50.0   RPM  None                          Capsule
# 1547                   NaN  None  None                           Tablet
# 1548                   NaN  None  None                           Tablet
# 1549                   NaN  None  None           Tablet, For Suspension
# 1550                   NaN  None  None                           Tablet
# 1551                   NaN  None  None                           Tablet
# 1552                   NaN  None  None                           Tablet
# 1553                  75.0   RPM  None                          Capsule
# 1554                   NaN  None  None                           Tablet
# 1555                   NaN  None  None                           Tablet
# 1556                   NaN  None  None                           Tablet
# 1557                  60.0   RPM  None                          Capsule
# 1558                  50.0   RPM  None                          Capsule
# 1559                  75.0   RPM  None                           Tablet
# 1560                  75.0   RPM  None                           Tablet
# 1561                  50.0   RPM  None                           Tablet
# 1562                  50.0   RPM  None                           Tablet
# 1563                  50.0   RPM  None                           Tablet
# 1564                   NaN  None  None                           Tablet
# 1565                  50.0   RPM  None                          Capsule
# 1566                  75.0   RPM  None                       Suspension
# 1567                  75.0   RPM  None                          Capsule
#
#                Release Type
# 1368                   None
# 1369                   None
# 1370                   None
# 1371                   None
# 1372  Orally Disintegrating
# 1373                   None
# 1374                   None
# 1375                   None
# 1376                   None
# 1377                   None
# 1378                   None
# 1379                   None
# 1380       Extended Release
# 1381                   None
# 1382                   None
# 1383                   None
# 1384                   None
# 1385                   None
# 1386                   None
# 1387                   None
# 1388                   None
# 1389                   None
# 1390                   None
# 1391                   None
# 1392                   None
# 1393                   None
# 1394                   None
# 1395                   None
# 1396                   None
# 1397                   None
# 1398                   None
# 1399                   None
# 1400                   None
# 1401               Chewable
# 1402             Sublingual
# 1403                   None
# 1404                   None
# 1405                   None
# 1406                   None
# 1407        Delayed Release
# 1408              Pediatric
# 1409                   None
# 1410                   None
# 1411                   None
# 1412                   None
# 1413       Extended Release
# 1414                   None
# 1415                   None
# 1416                   None
# 1417                   None
# 1418                   None
# 1419                   None
# 1420                   None
# 1421                   None
# 1422                   None
# 1423       Extended Release
# 1424                   None
# 1425                   None
# 1426                   None
# 1427                   None
# 1428                   None
# 1429                   None
# 1430                   None
# 1431                   None
# 1432                   None
# 1433                   None
# 1434                   None
# 1435                   None
# 1436                   None
# 1437                   None
# 1438                   None
# 1439                   None
# 1440                   None
# 1441                   None
# 1442                   None
# 1443                Vaginal
# 1444                   None
# 1445       Extended Release
# 1446       Extended Release
# 1447                   None
# 1448                   None
# 1449                   None
# 1450                   None
# 1451                   None
# 1452                   None
# 1453                   None
# 1454       Extended Release
# 1455       Extended Release
# 1456       Extended Release
# 1457       Extended Release
# 1458                   None
# 1459                   None
# 1460                   None
# 1461                   None
# 1462                   None
# 1463                   None
# 1464                   None
# 1465        Delayed Release
# 1466                   None
# 1467                   None
# 1468                   None
# 1469                   None
# 1470                   None
# 1471                   None
# 1472       Extended Release
# 1473                   None
# 1474                   None
# 1475       Extended Release
# 1476                   None
# 1477                   None
# 1478               Sprinkle
# 1479       Extended Release
# 1480       Extended Release
# 1481                   None
# 1482                   None
# 1483                   None
# 1484                   None
# 1485       Extended Release
# 1486       Extended Release
# 1487                   None
# 1488                   None
# 1489                   None
# 1490       Extended Release
# 1491                   None
# 1492                   None
# 1493       Extended Release
# 1494                   None
# 1495       Extended Release
# 1496                   None
# 1497                   None
# 1498       Extended Release
# 1499                   None
# 1500                   None
# 1501                   None
# 1502                   None
# 1503       Extended Release
# 1504                   None
# 1505       Extended Release
# 1506                   None
# 1507                   None
# 1508                   None
# 1509       Extended Release
# 1510                   None
# 1511                   None
# 1512                   None
# 1513                   None
# 1514                   None
# 1515               Sprinkle
# 1516                   None
# 1517                   None
# 1518                   None
# 1519                   None
# 1520                   None
# 1521                   None
# 1522                   None
# 1523                   None
# 1524  Orally Disintegrating
# 1525                   None
# 1526                   None
# 1527                   None
# 1528       Extended Release
# 1529       Extended Release
# 1530       Extended Release
# 1531                   None
# 1532       Extended Release
# 1533       Extended Release
# 1534                   None
# 1535                   None
# 1536                   None
# 1537                   None
# 1538                   None
# 1539                   None
# 1540       Extended Release
# 1541                   None
# 1542                   None
# 1543                   None
# 1544                   None
# 1545                   None
# 1546                   None
# 1547                   None
# 1548                   None
# 1549                   None
# 1550                   None
# 1551                   None
# 1552                   None
# 1553                   None
# 1554                   None
# 1555       Extended Release
# 1556                   None
# 1557                   None
# 1558                   None
# 1559  Orally Disintegrating
# 1560                   None
# 1561                   None
# 1562       Extended Release
# 1563             Sublingual
# 1564             Sublingual
# 1565                   None
# 1566                   None
# 1567                   None

# %% [markdown]
# Running functions to clean up dataset.

# %%
test = "75 "

# Define globally
rpm_case_tracking_dict = {
    "Case: empty entry": 0,
    "Case: pure number": 0,
    "Case: number + unit": 0,
    "Case: number with unit embedded": 0,
    "Case: \"X mg, Y mg and Z mg: N rpm\"": 0,
    "Case: \"<Note>: <number> [unit?]\"": 0,
    "Fallback: keep as note": 0,
}

# Setting for which cases to print
rpm_case_printing_dict = {
    "Case: empty entry": False,
    "Case: pure number": False,
    "Case: number + unit": True,
    "Case: number with unit embedded": True,
    "Case: \"X mg, Y mg and Z mg: N rpm\"": True,
    "Case: \"<Note>: <number> [unit?]\"": True,
    "Fallback: keep as note": True,
}

def clean_speed_entry(entry):
    """
    Returns a list of tuples: (Speed, Unit, Notes)
    Handles multiple numbers per entry and colon/semicolon-separated cases.
    """
    if pd.isna(entry):
        rpm_case_tracking_dict["Case: empty entry"] += 1
        if rpm_case_printing_dict["Case: empty entry"] == True:
            print("Case: empty entry                    ", (None, None, None))
        return [(None, None, None)]

    # Replacing any Unicode non-breaking space characters ("\xa0") with spaces
    # val = str(entry).replace("\xa0", " ").strip()
    
    # Replace non-breaking spaces and collapse all whitespace in one go
    val = re.sub(r'\s+', ' ', str(entry).replace("\xa0", " ")).strip()

    results = []

    # Split by semicolons for multiple measurements
    parts = [p.strip() for p in val.split(";")]

    for part in parts:
        # Case: pure number
        if part.isdigit():
            results.append((int(part), "RPM", None))
            rpm_case_tracking_dict["Case: pure number"] += 1
            if rpm_case_printing_dict["Case: pure number"] == True:
                print("Case: pure number                    ", (int(part), "RPM", None))
            continue

        # Case: number + unit
        match = re.match(r"(\d+)\s*([A-Za-z/ ]+)", part)
        if match and match.group(2) != '':
            speed = int(match.group(1))
            unit = match.group(2).strip().replace("per minute", "/min")
            results.append((speed, unit, None))
            rpm_case_tracking_dict["Case: number + unit"] += 1
            if rpm_case_printing_dict["Case: number + unit"] == True:
                print("Case: number + unit                  ", (speed, unit, None))
            continue

        # Case: number with unit embedded
        embedded = re.search(r"(\d+)\s*(rpm|dpm|cycles per min|cycles/min)", part, flags=re.I)
        if embedded:
            speed = int(embedded.group(1))
            unit = RPM_UNIT_MAP.get(embedded.group(2).lower(), embedded.group(2).upper())
            # Remove speed/unit from note
            note = re.sub(r"\d+\s*" + embedded.group(2), "", part, flags=re.I).strip(",; ")
            results.append((speed, unit, note if note else None))
            rpm_case_tracking_dict["Case: number with unit embedded"] += 1
            if rpm_case_printing_dict["Case: number with unit embedded"] == True:
                print("Case: number with unit embedded")
            continue
            
        # Case: "X mg, Y mg and Z mg: N rpm"
        multi_match = re.match(r"([\d, andmgMG ]+):\s*(\d+)\s*([A-Za-z/]+)?", part)
        if multi_match:
            drugs = re.split(r",|and", multi_match.group(1))
            speed = int(multi_match.group(2))
            unit = multi_match.group(3).lower() if multi_match.group(3) else "rpm"
            unit = RPM_UNIT_MAP.get(unit.lower(), unit.upper())
            for d in [d.strip() for d in drugs if d.strip()]:
                results.append((speed, unit, d))
            rpm_case_tracking_dict["Case: \"X mg, Y mg and Z mg: N rpm\""] += 1
            if rpm_case_printing_dict["Case: \"X mg, Y mg and Z mg: N rpm\""] == True:
                print("Case: \"X mg, Y mg and Z mg: N rpm\"")
            continue

        # Case: "<Note>: <number> [unit?]"
        colon_match = re.match(r"(.+?):\s*(\d+)\s*([A-Za-z/]+)?", part)
        if colon_match:
            note = colon_match.group(1).strip()
            speed = int(colon_match.group(2))
            unit = colon_match.group(3).lower() if colon_match.group(3) else None
            if unit:
                unit = RPM_UNIT_MAP.get(unit.lower(), unit.upper())
            results.append((speed, unit, note))
            rpm_case_tracking_dict["Case: \"<Note>: <number> [unit?]\""] += 1
            if rpm_case_printing_dict["Case: \"<Note>: <number> [unit?]\""] == True:
                print("Case: \"<Note>: <number> [unit?]\"")
            continue

        # Fallback: keep as note
        results.append((None, None, part))
        rpm_case_tracking_dict["Fallback: keep as note"] += 1
        if rpm_case_printing_dict["Fallback: keep as note"] == True:
            print("Fallback: keep as note               ", (None, None, part))
            
    return results

# Apply and expand, safely overwriting existing columns
expanded_test = clean_speed_entry(test)
expanded_test
# Out:
# [(75, 'RPM', None)]

# %%
# Apply and expand "Dosage Form" data into two new columns
df[["Dosage Form (Clean)", "Release Type"]] = df["Dosage Form"].apply(lambda x: pd.Series(clean_dosage_form(x)))
expanded_test
# # Check results
# print(df['DosageForm_clean'].value_counts())
# print(df['ReleaseType'].value_counts())


# # Example transformations
# # Performing dataset cleanup as needed before one-hot encoding
# df['num_sampling_times'] = df['SamplingTimes'].apply(lambda x: len(str(x).split(',')))
# df['max_sampling_time'] = df['SamplingTimes'].apply(lambda x: max([int(t) for t in str(x).split(',')]))

# # One-hot encode categorical variables
# df_encoded = pd.get_dummies(df[['Apparatus', 'MediumType', 'DosageForm']])

# # Combine numeric + encoded
# features = pd.concat([df[['RPM', 'MediumVolume', 'num_sampling_times', 'max_sampling_time']], df_encoded], axis=1)


# # Drop non-numeric columns if needed after feature engineering is complete (sanity check)
# df = df.select_dtypes(include=[np.number]).dropna()

# features.head()
# Out:
# [(75, 'RPM', None)]

# %%
df[df.columns[-2]].value_counts()
# Out:
# Dosage Form (Clean)
# Tablet                                                971
# Capsule                                               335
# Suspension                                             67
# Oral Suspension                                        17
# Film, Transdermal                                      14
# For Suspension                                         11
# Ophthalmic Suspension                                   9
# Film                                                    8
# Transdermal                                             8
# Injectable Suspension                                   8
# Injectable                                              7
# For Oral Suspension                                     6
# Granule                                                 6
# Implant                                                 6
# Suppository                                             5
# Gel                                                     4
# Vaginal Insert                                          3
# Tablet/Tablet                                           3
# Rectal Suppository                                      3
# Capsules                                                3
# Otic Suspension                                         3
# Tablet, For Suspension                                  3
# Pellets                                                 3
# Powder For Suspension                                   3
# Otc Tablet                                              3
# Lozenge                                                 3
# Topical Patch                                           3
# For Intramuscular Suspension                            3
# Transdermal System                                      2
# Granules                                                2
# Vaginal Ring                                            2
# Capsule/Tablet/Capsule                                  2
# Intramuscular Suspension                                2
# Tablets                                                 2
# Powder                                                  2
# Powder For Oral                                         2
# Emulsion                                                2
# Solution                                                1
# Delayed Release Granules For Oral Suspension            1
# Trans-Dermal                                            1
# Capsule, Tablet                                         1
# Chewing Gum                                             1
# Granules, For Oral Suspension                           1
# Buccal Tablet                                           1
# Er Tablets                                              1
# Capsule, Tablet, Tablet                                 1
# Pellet Implant                                          1
# Transdermal Patch                                       1
# Rectal Enema                                            1
# Intrauterine Device                                     1
# Topical Suspension                                      1
# Chewable Tablet                                         1
# Injectable Suspension [Otic]                            1
# Extended Release Oral Suspension                        1
# Tablet, Chewable                                        1
# Powder For Injection                                    1
# Sublingual Film                                         1
# Solution (Extended Release), Infiltration               1
# Powder For Oral Solution                                1
# Vaginal Suppository                                     1
# Bisub: Tablet (Chewable) /Met:Tablet /Tet: Capsule      1
# Tablet (Delayed Release), For Solution                  1
# Oral Granule                                            1
# Granules For Oral Suspension                            1
# Vaginal Tablet                                          1
# Lozenges                                                1
# Tablet (Extended Release                                1
# Suspension/Drop                                         1
# Intra-Articular, For Suspension                         1
# Name: count, dtype: int64

# %%
df[df.columns[-1]].value_counts()
# Out:
# Release Type
# Extended Release                           209
# Delayed Release                             51
# Chewable                                    26
# Orally Disintegrating                       24
# Sublingual                                  10
# Copackage                                    8
# Buccal                                       7
# Soft-Gelatin                                 5
# Orally Disintegrating (ODT)                  4
# Vaginal                                      3
# For Suspension                               2
# Soft-Gelatin/Liquid Fill                     2
# Delayed Release Pellets                      2
# Delayed Release, Orally Disintegrating       2
# Sprinkle                                     2
# Liposomal                                    2
# Extended Release, Orally Disintegrating      2
# Effervescent                                 2
# Dental                                       1
# Chewable dispersible                         1
# Pediatric                                    1
# Copackaged                                   1
# Oral                                         1
# Immediate Release                            1
# Mini                                         1
# Extended Release, Chewable                   1
# Combination                                  1
# Regular                                      1
# Micronized                                   1
# Regular & Chewable                           1
# Orally Disintegrating, Delayed Release       1
# Pellet                                       1
# Intravitreal                                 1
# For Oral Suspension                          1
# Enteral                                      1
# Intravenous                                  1
# Liquid filled                                1
# Topical                                      1
# Name: count, dtype: int64

# %% [markdown]
# #### 3.2. Preprocessing
#
# In this case, all of the columns except the target column are going to be used to predict the target column.
#
# In other words, using a patient's medical and demographic data to predict whether or not they have heart disease.

# %% [markdown]
# #### 3.3. Feature Engineering
#
# In this case, a selection of synthetic dissolution profiles will be simulated from the FDA metadata (dosage form, apparatus type, agitation speed (rpm), medium composition, medium volume, and sampling times). For instance, a first-order or Weibull kinetic model may be used to generate curves plotting the percentage of the drug dissolved over time. Parameters can parhaps be linked to method settings (e.g., higher RPM values could lead to faster rate constants).
#
# After this, it will be possible to use GMMs within a Machine Learning workflow and a patient's medical and demographic data to predict whether or not they have heart disease.

# %%
# Create X (all the feature columns)
X = heart_disease.drop("target", axis=1)

# Create y (the target column)
y = heart_disease["target"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Create X (all the feature columns)
# ----> 2 X = heart_disease.drop("target", axis=1)
#       4 # Create y (the target column)
#       5 y = heart_disease["target"]
#
# NameError: name 'heart_disease' is not defined

# %%
# Split the data into training and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# View the data shapes
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %% [markdown]
# 1. Problem defintion
# 2. Data
# 3. Evaluation
# 4. Features
# 5. Modelling
# 6. Experiments
